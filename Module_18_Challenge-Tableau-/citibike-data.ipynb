# %%
# Import required libraries and dependencies
import pandas as pd

# %%
# List of file names to be combined 
files19 = ['jan2019-data.csv', 'july2019-data.csv']

# Create an empty list to store each dataframe
df19_list = []

# Loop through each file in the list
for file in files19:
    # Read the file into a dataframe
    df19 = pd.read_csv(file)

    # Append the dataframe to the list
    df19_list.append(df19)

# Concatenate all dataframes in the list into one dataframe
df19 = pd.concat(df19_list)

# Show dataframe
df19
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                 316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                 591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3                2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                 303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...               ...                       ...                       ...
# 2181059           644  2019-07-31 23:59:45.2950  2019-08-01 00:10:29.8640
# 2181060           589  2019-07-31 23:59:52.7170  2019-08-01 00:09:42.0870
# 2181061          1302  2019-07-31 23:59:52.8280  2019-08-01 00:21:35.1090
# 2181062           353  2019-07-31 23:59:57.1130  2019-08-01 00:05:50.1350
# 2181063           274  2019-07-31 23:59:57.4870  2019-08-01 00:04:32.2070
#
#          start station id              start station name  \
# ...

# %%
# Dictionary mapping values in the 'gender' column to new values
mapping = {0: 'Unknown', 1: 'Male', 2: 'Female'}

# Use the 'map' method to change the values in the 'gender' column
df19['gender'] = df19['gender'].map(mapping)

# Show DataFrame
df19
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                 316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                 591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3                2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                 303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...               ...                       ...                       ...
# 2181059           644  2019-07-31 23:59:45.2950  2019-08-01 00:10:29.8640
# 2181060           589  2019-07-31 23:59:52.7170  2019-08-01 00:09:42.0870
# 2181061          1302  2019-07-31 23:59:52.8280  2019-08-01 00:21:35.1090
# 2181062           353  2019-07-31 23:59:57.1130  2019-08-01 00:05:50.1350
# 2181063           274  2019-07-31 23:59:57.4870  2019-08-01 00:04:32.2070
#
#          start station id              start station name  \
# ...

# %%
df19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3148351 entries, 0 to 2181063
# Data columns (total 15 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             int64
#  1   starttime                object
#  2   stoptime                 object
#  3   start station id         float64
#  4   start station name       object
#  5   start station latitude   float64
#  6   start station longitude  float64
#  7   end station id           float64
#  8   end station name         object
#  9   end station latitude     float64
#  10  end station longitude    float64
#  11  bikeid                   int64
#  12  usertype                 object
#  13  birth year               int64
#  14  gender                   object
# dtypes: float64(6), int64(3), object(6)
# memory usage: 384.3+ MB

# %%
df19 = df19.dropna()

# %%
# Save the dataframe to a CSV file
df19.to_csv('citibike-19.csv', index=False)
